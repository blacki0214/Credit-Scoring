# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Asus\Documents\GitHub\Credit-Scoring\data\fico_style_features.csv')

# %%
df.info()
df.describe()
df.isnull().mean().sort_values(ascending=False).head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   SK_ID_CURR               307511 non-null  int64
#  1   TARGET                   307511 non-null  int64
#  2   dpd_mean                 307511 non-null  float64
#  3   dpd_max                  307511 non-null  float64
#  4   on_time_ratio            307511 non-null  float64
#  5   num_payments             307511 non-null  float64
#  6   AMT_CREDIT_SUM           307511 non-null  float64
#  7   AMT_CREDIT_SUM_DEBT      307511 non-null  float64
#  8   CREDIT_ACTIVE_FLAG       307511 non-null  float64
#  9   total_utilization        307511 non-null  float64
#  10  credit_card_utilization  307511 non-null  float64
#  11  oldest_account_m         307511 non-null  float64
#  12  newest_account_m         307511 non-null  float64
#  13  aaoa_m                   307511 non-null  float64
#  14  thin_file_flag           307511 non-null  int64
# dtypes: float64(12), int64(3)
# memory usage: 35.2 MB
# SK_ID_CURR             0.0
# TARGET                 0.0
# dpd_mean               0.0
# dpd_max                0.0
# on_time_ratio          0.0
# num_payments           0.0
# AMT_CREDIT_SUM         0.0
# AMT_CREDIT_SUM_DEBT    0.0
# CREDIT_ACTIVE_FLAG     0.0
# total_utilization      0.0
# dtype: float64

# %%
# Kiểm tra dữ liệu có bị mất cân bằng không(Kết quả cho thấy dữ liệu bị mất cân bằng, điều chỉnh trong training)
df['TARGET'].value_counts(normalize=True)
# Out:
# TARGET
# 0    0.919271
# 1    0.080729
# Name: proportion, dtype: float64

# %%
df.corr(numeric_only=True)['TARGET'].sort_values(ascending=False).head(10)
# Out:
# TARGET                     1.000000
# credit_card_utilization    0.054346
# total_utilization          0.045932
# CREDIT_ACTIVE_FLAG         0.043569
# thin_file_flag             0.030533
# dpd_mean                   0.008281
# dpd_max                    0.004467
# AMT_CREDIT_SUM_DEBT        0.001895
# SK_ID_CURR                -0.002108
# num_payments              -0.016310
# Name: TARGET, dtype: float64
